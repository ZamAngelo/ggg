# %%
# !pip install pandas 
# !pip install matplotlip
# !pip install yfinance

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import yfinance as yf

# %%
df = pd.DataFrame
misactivos =[]

# %%
def ext():
     num = int(input("coloca numero acciones"))
     inicio=input("fecha inicio")
     final=input("fecha final")
     for i in range(num):

          activos=input("nombre accion")
          misactivos.append(activos)
     return yf.download(misactivos,start=inicio,end=final)["Adj Close"]

# %%
df = ext()
# Out:
# Could not get exchangeTimezoneName for ticker '' reason: list index out of range
# [*********************100%%**********************]  9 of 9 completed
#
# 1 Failed download:
# ['']: %ticker%E%ticker%x%ticker%c%ticker%e%ticker%p%ticker%t%ticker%i%ticker%o%ticker%n%ticker%(%ticker%'%ticker%:%ticker% %ticker%N%ticker%o%ticker% %ticker%t%ticker%i%ticker%m%ticker%e%ticker%z%ticker%o%ticker%n%ticker%e%ticker% %ticker%f%ticker%o%ticker%u%ticker%n%ticker%d%ticker%,%ticker% %ticker%s%ticker%y%ticker%m%ticker%b%ticker%o%ticker%l%ticker% %ticker%m%ticker%a%ticker%y%ticker% %ticker%b%ticker%e%ticker% %ticker%d%ticker%e%ticker%l%ticker%i%ticker%s%ticker%t%ticker%e%ticker%d%ticker%'%ticker%)%ticker%

# %%
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kwargs)>

# %%
df.to_excel("D:/PROYECTOS SQL PYTHON JS HTML ETC/PORTAFOLIO PYTHO/portafolio.xlsx")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.to_excel("D:/PROYECTOS SQL PYTHON JS HTML ETC/PORTAFOLIO PYTHO/portafolio.xlsx")
#
# NameError: name 'df' is not defined

# %%
df=pd.read_excel("D:/PROYECTOS SQL PYTHON JS HTML ETC/PORTAFOLIO PYTHO/portafolio.xlsx")

# %%
df.head()
# Out:
#         Date   cd       AMZN        AVGO        BAC         LLY        META  \
# 0 2020-01-02  0.0  94.900497  282.428558  32.048061  124.506012  209.557648
# 1 2020-01-03  NaN  93.748497  275.245026  31.382641  124.091637  208.448837
# 2 2020-01-06  0.0  95.143997  274.833282  31.337671  124.553078  212.374680
# 3 2020-01-07  0.0  95.343002  273.887146  31.130857  124.788528  212.834183
# 4 2020-01-08  0.0  94.598503  270.470520  31.445587  125.918648  214.991898
#
#          MSFT       NVDA         PXD
# 0  154.493790  59.741245  119.396927
# 1  152.570114  58.785027  120.188515
# 2  152.964478  59.031544  123.919197
# 3  151.569809  59.746216  123.010033
# 4  153.984039  59.858273  119.193161

# %%
df["cd"].fillna(0,inplace=True)
df.head()

#El argumento inplace se utiliza en varias funciones en bibliotecas de Python como pandas. Cuando inplace se establece en True, la operación se realiza en el objeto original y se modifica. Por otro lado, cuando inplace se establece en False (que es el valor predeterminado), la operación no afecta al objeto original y en su lugar devuelve una copia del objeto con la operación aplicada1.

#Por ejemplo, en el caso de la función rename de pandas, si usas inplace=True, cambiará los nombres de las columnas del DataFrame original. Si usas inplace=False, mantendrá intacto el DataFrame original y devolverá un nuevo DataFrame con los nombres de las columnas cambiados1.
# Out:
#         Date   cd       AMZN        AVGO        BAC         LLY        META  \
# 0 2020-01-02  0.0  94.900497  282.428558  32.048061  124.506012  209.557648
# 1 2020-01-03  0.0  93.748497  275.245026  31.382641  124.091637  208.448837
# 2 2020-01-06  0.0  95.143997  274.833282  31.337671  124.553078  212.374680
# 3 2020-01-07  0.0  95.343002  273.887146  31.130857  124.788528  212.834183
# 4 2020-01-08  0.0  94.598503  270.470520  31.445587  125.918648  214.991898
#
#          MSFT       NVDA         PXD
# 0  154.493790  59.741245  119.396927
# 1  152.570114  58.785027  120.188515
# 2  152.964478  59.031544  123.919197
# 3  151.569809  59.746216  123.010033
# 4  153.984039  59.858273  119.193161

# %%
df["nuevo"]=None
df.head()
# Out:
#         Date   cd       AMZN        AVGO        BAC         LLY        META  \
# 0 2020-01-02  0.0  94.900497  282.428558  32.048061  124.506012  209.557648
# 1 2020-01-03  0.0  93.748497  275.245026  31.382641  124.091637  208.448837
# 2 2020-01-06  0.0  95.143997  274.833282  31.337671  124.553078  212.374680
# 3 2020-01-07  0.0  95.343002  273.887146  31.130857  124.788528  212.834183
# 4 2020-01-08  0.0  94.598503  270.470520  31.445587  125.918648  214.991898
#
#          MSFT       NVDA         PXD nuevo
# 0  154.493790  59.741245  119.396927  None
# 1  152.570114  58.785027  120.188515  None
# 2  152.964478  59.031544  123.919197  None
# 3  151.569809  59.746216  123.010033  None
# 4  153.984039  59.858273  119.193161  None

# %%
df["AMZN"].max()
df.max()
# Out:
# Date     2023-12-29 00:00:00
# cd                       0.0
# AMZN              186.570496
# AVGO             1136.908203
# BAC                46.471874
# LLY                616.90686
# META              381.774933
# MSFT              381.993622
# NVDA              504.022034
# PXD               249.435532
# nuevo                   None
# dtype: object

# %%
df.std()
# Out:
#            cd         AMZN         AVGO          BAC          LLY  \
# count  1006.0  1006.000000  1006.000000  1006.000000  1006.000000
# mean      0.0   137.216247   508.122316    31.559638   280.383470
# std       0.0    27.468805   194.235467     6.611959   131.388142
# min       0.0    81.820000   147.061920    16.361565   112.693954
# 25%       0.0   114.309002   393.581398    27.088912   160.840076
# 50%       0.0   140.585007   473.913223    31.229772   254.092873
# 75%       0.0   161.190620   581.818298    36.148243   342.808540
# max       0.0   186.570496  1136.908203    46.471874   616.906860
#
#               META         MSFT         NVDA          PXD
# count  1006.000000  1006.000000  1006.000000  1006.000000
# mean    249.097970   258.083110   210.755707   157.361190
# std      70.927427    55.651986   117.594366    58.701145
# min      88.815765   130.610748    48.935848    44.493664
# 25%     193.359844   216.099621   131.301971   106.908625
# ...

# %%
df.count()
# Out:
# Date     1006
# cd       1006
# AMZN     1006
# AVGO     1006
# BAC      1006
# LLY      1006
# META     1006
# MSFT     1006
# NVDA     1006
# PXD      1006
# nuevo       0
# dtype: int64

# %%
df.describe()
# Out:
#            cd         AMZN         AVGO          BAC          LLY  \
# count  1006.0  1006.000000  1006.000000  1006.000000  1006.000000
# mean      0.0   137.216247   508.122316    31.559638   280.383470
# std       0.0    27.468805   194.235467     6.611959   131.388142
# min       0.0    81.820000   147.061920    16.361565   112.693954
# 25%       0.0   114.309002   393.581398    27.088912   160.840076
# 50%       0.0   140.585007   473.913223    31.229772   254.092873
# 75%       0.0   161.190620   581.818298    36.148243   342.808540
# max       0.0   186.570496  1136.908203    46.471874   616.906860
#
#               META         MSFT         NVDA          PXD
# count  1006.000000  1006.000000  1006.000000  1006.000000
# mean    249.097970   258.083110   210.755707   157.361190
# std      70.927427    55.651986   117.594366    58.701145
# min      88.815765   130.610748    48.935848    44.493664
# 25%     193.359844   216.099621   131.301971   106.908625
# ...

# %%
df.transpose()
# Out:
#                       0                    1                    2     \
# Date   2020-01-02 00:00:00  2020-01-03 00:00:00  2020-01-06 00:00:00
# cd                     0.0                  0.0                  0.0
# AMZN             94.900497            93.748497            95.143997
# AVGO            282.428558           275.245026           274.833282
# BAC              32.048061            31.382641            31.337671
# LLY             124.506012           124.091637           124.553078
# META            209.557648           208.448837            212.37468
# MSFT             154.49379           152.570114           152.964478
# NVDA             59.741245            58.785027            59.031544
# PXD             119.396927           120.188515           123.919197
# nuevo                 None                 None                 None
#
#                       3                    4                    5     \
# ...

# %%
df["AMZN"].nunique()
df["AMZN"].unique()
# Out:
# array([ 94.90049744,  93.74849701,  95.14399719,  95.34300232,
#         94.59850311,  95.05249786,  94.15799713,  94.56500244,
#         93.47200012,  93.10099792,  93.89700317,  93.23600006,
#         94.59999847,  94.3730011 ,  94.22899628,  93.08200073,
#         91.41699982,  92.66249847,  92.90000153,  93.53399658,
#        100.43599701, 100.20999908, 102.48349762, 101.99349976,
#        102.5114975 , 103.96399689, 106.69550323, 107.54000092,
#        108.        , 107.49349976, 106.74349976, 107.78350067,
#        108.51100159, 107.65499878, 104.79850006, 100.46450043,
#         98.63700104,  98.97949982,  94.21499634,  94.1875    ,
#         97.69750214,  95.44950104,  98.79149628,  96.20149994,
#         95.05449677,  90.03050232,  94.59100342,  91.04299927,
#         83.83049774,  89.25      ,  84.45749664,  90.39199829,
#         91.5       ,  94.04650116,  92.30449677,  95.14150238,
#         97.00499725,  94.29199982,  97.77449799,  95.00499725,
# ...

# %%
df["AMZN"].value_counts()
# Out:
# 125.980003    3
# 138.229996    2
# 147.419998    2
# 166.100006    2
# 135.360001    2
#              ..
# 165.593506    1
# 163.526993    1
# 165.318497    1
# 164.580505    1
# 151.940002    1
# Name: AMZN, Length: 985, dtype: int64

# %%
df["CALCULO"]=df["TSLA"]*df["SPOT"]

# %%
df.query("BAC<NVDA & MSFT > META")
# Out:
# Empty DataFrame
# Columns: [Date, cd, AMZN, AVGO, BAC, LLY, META, MSFT, NVDA, PXD, new2]
# Index: []

# %%
plt.plot(df)

# %%
#cuando se requiere hacer una funcion con dos parametros se puede hacer lo siguiente, por cada activo:
"""def act(activos,inicio,final):
     df = yf.download(activos, start=inicio, end=final)["Adj Close"]
     return df""""
# Out:
#   Cell In[9], line 4
#     return df""""
#                 ^
# SyntaxError: unterminated string literal (detected at line 4)

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df["new2"]=None

# %%
df
# Out:
#            Date   cd        AMZN         AVGO        BAC         LLY  \
# 0    2020-01-02  0.0   94.900497   282.428558  32.048061  124.506012
# 1    2020-01-03  NaN   93.748497   275.245026  31.382641  124.091637
# 2    2020-01-06  0.0   95.143997   274.833282  31.337671  124.553078
# 3    2020-01-07  0.0   95.343002   273.887146  31.130857  124.788528
# 4    2020-01-08  0.0   94.598503   270.470520  31.445587  125.918648
# ...         ...  ...         ...          ...        ...         ...
# 1001 2023-12-22  0.0  153.419998  1117.222046  33.196156  569.391968
# 1002 2023-12-26  0.0  153.410004  1127.089966  33.623150  569.671448
# 1003 2023-12-27  0.0  153.339996  1121.394287  33.603287  580.492493
# 1004 2023-12-28  0.0  153.380005  1117.650269  33.643009  579.833618
# 1005 2023-12-29  0.0  151.940002  1111.516357  33.434475  581.900024
#
#             META        MSFT        NVDA         PXD
# 0     209.557648  154.493790   59.741245  119.396927
# ...

# %%
# Digamos que quieres mantener las filas con índices 1 y 3
indices_a_mantener = ["AMZN","BAC"]

# Usamos una comprensión de lista para seleccionar todos los índices excepto los que queremos mantener
indices_a_eliminar = [i for i in df.columns if i not in indices_a_mantener]


# Eliminamos esos índices del DataFrame
#df = df.drop(indices_a_eliminar)

# Eliminamos esos índices del DataFrame pero en este caso el axis=1 hace referencia a que toma en cuenta columnas
df = df.drop(indices_a_eliminar, axis=1)

df.head()
# Out:
#         AMZN        BAC
# 0  94.900497  32.048061
# 1  93.748497  31.382641
# 2  95.143997  31.337671
# 3  95.343002  31.130857
# 4  94.598503  31.445587

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [Date, cd, AMZN, AVGO, BAC, LLY, META, MSFT, NVDA, PXD]
# Index: []

# %%
import pandas as pd
bas = pd.read_excel("C:/Users/Zam Angelo/Downloads/BASE CARTERA 01 DIC.xlsx")

# %%
bas.filter(regex="r$",axis=1) # encuentra columnas que tengan la palabra r
# Out:
#      Gender
# 0    Female
# 1    Female
# 2      Male
# 3      Male
# 4      Male
# ..      ...
# 995    Male
# 996  Female
# 997    Male
# 998    Male
# 999  Female
#
# [1000 rows x 1 columns]

# %%
bas
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
bas.loc[0]
# Out:
# Fechareporte              2023-12-01 00:00:00
# Rfc                             IIZC6305026RA
# Nombrecompleto         CARLOS INIESTRA ZUÑIGA
# Sector                                     32
# Linea                              1821580028
#                                 ...
# Cre Califi                                NaN
# Fechabajaexempleado                       NaN
# Tasa Inicial                          14.5033
# Lin Clasif                                  3
# Cla Descri                            Consumo
# Name: 0, Length: 72, dtype: object

# %%
bas.loc[[1,2],["City","Gender"]]
# Out:
#         City  Gender
# 1  Naypyitaw  Female
# 2     Yangon    Male

# %%
bas.groupby("Sector").count()
# Out:
#         Fechareporte  Rfc  Nombrecompleto  Linea  Fechavencimientolínea  \
# Sector
# 32                60   60              60     60                     60
#
#         Capitalotorgado  Tipocredito  Numerocredito  Cobrointereses  \
# Sector
# 32                   60           60             60              60
#
#         Fechainicioamortizacion  ...  Formulatasa  Descripciontasa  Puntotasa  \
# Sector                           ...
# 32                           60  ...           60               60         60
#
#         EtapaFinal  Cre Resfin  Cre Califi  Fechabajaexempleado  Tasa Inicial  \
# Sector
# 32              60           0           0                    0            60
#
#         Lin Clasif  Cla Descri
# Sector
# 32              60          60
#
# [1 rows x 71 columns]

# %%
del bas["Fechabajaexempleado"]

# %%
pip install pandas openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
parte = pd.ExcelWriter("C:/Users/Zam Angelo/Downloads/BASE CARTERA 01 DIC.xlsx")
consulta.to_excel(parte,"hoja prueba", index=False)
parte.save()
parte.close()
# Out:
# C:\Users\Zam Angelo\AppData\Local\Temp\ipykernel_10820\3380042735.py:4: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   parte.save()

# %%
consulta = bas.query('Branch=="A"')
consulta
# Out:
#       Invoice ID Branch    City Customer type  Gender            Product line  \
# 0    750-67-8428      A  Yangon        Member  Female       Health and beauty
# 2    631-41-3108      A  Yangon        Normal    Male      Home and lifestyle
# 3    123-19-1176      A  Yangon        Member    Male       Health and beauty
# 4    373-73-7910      A  Yangon        Normal    Male       Sports and travel
# 6    355-53-5943      A  Yangon        Member  Female  Electronic accessories
# ..           ...    ...     ...           ...     ...                     ...
# 990  886-18-2897      A  Yangon        Normal  Female      Food and beverages
# 992  745-74-0715      A  Yangon        Normal    Male  Electronic accessories
# 997  727-02-1313      A  Yangon        Member    Male      Food and beverages
# 998  347-56-2442      A  Yangon        Normal    Male      Home and lifestyle
# 999  849-09-3807      A  Yangon        Member  Female     Fashion accessories
#
# ...

# %%
bas[bas["Gender"]=="Female"]
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 6    355-53-5943      A     Yangon        Member  Female
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# 8    665-32-9167      A     Yangon        Member  Female
# ..           ...    ...        ...           ...     ...
# 990  886-18-2897      A     Yangon        Normal  Female
# 991  602-16-6955      B   Mandalay        Normal  Female
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 996  303-96-2227      B   Mandalay        Normal  Female
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
# filtrar filas metodo filter
bas.set_index("Gender").filter(like='Female', axis=0)
# Out:
#          Invoice ID Branch       City Customer type            Product line  \
# Gender
# Female  750-67-8428      A     Yangon        Member       Health and beauty
# Female  226-31-3081      C  Naypyitaw        Normal  Electronic accessories
# Female  355-53-5943      A     Yangon        Member  Electronic accessories
# Female  315-22-5665      C  Naypyitaw        Normal      Home and lifestyle
# Female  665-32-9167      A     Yangon        Member       Health and beauty
# ...             ...    ...        ...           ...                     ...
# Female  886-18-2897      A     Yangon        Normal      Food and beverages
# Female  602-16-6955      B   Mandalay        Normal       Sports and travel
# Female  652-49-6720      C  Naypyitaw        Member  Electronic accessories
# Female  303-96-2227      B   Mandalay        Normal      Home and lifestyle
# Female  849-09-3807      A     Yangon        Member     Fashion accessories
#
# ...

# %%
exthtml = pd.read_html("https://www.wsj.com/market-data/stocks")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 exthtml = pd.read_html("https://www.wsj.com/market-data/stocks")
#
# File c:\Users\Zam Angelo\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\Zam Angelo\anaconda3\lib\site-packages\pandas\io\html.py:1205, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links)
# ...

# %%
exthtml[0]
# Out:
#                                     S&P 500  \
# 0                                       NaN
# 1   Evolución del S&P 500 entre 1950 y 2016
# 2                                      País
# 3                                  Operador
# 4                                     Bolsa
# 5                                  Creación
# 6                               Componentes
# 7                                      ISIN
# 8                                       NaN
# 9                              Relacionados
# 10               [editar datos en Wikidata]
#
#                                   S&P 500.1  \
# 0                                       NaN
# 1   Evolución del S&P 500 entre 1950 y 2016
# 2                            Estados Unidos
# 3                 Índice bursátil Dow Jones
# 4              Bolsa de Nueva York y NASDAQ
# 5     4 de marzo de 1957[1]​ (hace 67 años)
# 6                                   506[2]​
# 7                              US78378X1072
# ...
